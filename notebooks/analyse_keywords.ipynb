# %%
import pandas as pd

# %%
df1 = pd.read_csv('../data/jobposts/20250525-vancouver.csv')
df2 = pd.read_csv('../data/jobposts/20250526-vancouver.csv')

df = pd.concat([df1, df2])

# %%
# count
print(df.shape)
print(df['job_url'].unique().shape)
# Out:
# (38240, 6)
# (21087,)

# %%
# clean keywords
tmp = df['position'].str.lower() + ' ' + df['company'].str.lower()
tmp = tmp.apply(lambda text : ''.join(c if c.isalpha() else ' ' for c in text))
tmp = tmp.str.split().apply(set)
df['keywords'] = tmp.apply(lambda kws: {w for w in kws if len(w) > 2})

# get word frequencies
keywords = ' '.join(df['keywords'].str.join(' ')).split()
wf_data = [{'keyword' : w, 'count' : keywords.count(w)} for w in set(keywords)]

# rank keywords
wf = pd.DataFrame(wf_data)
wf = wf.sort_values('count', ascending=False)
wf['rank'] = range(len(wf))
wf = wf.set_index('keyword')

rank_dict = wf.to_dict()['rank']
df['word_ranks'] = df['keywords'].apply(lambda words : [rank_dict[word] for word in words if word in rank_dict])
df['min_rank'] = df['word_ranks'].apply(lambda x : min(x) if x else None)

# characteristic rank of job in Vancouver
df['mean_rank'] = df['word_ranks'].apply(lambda x : sum(x)/len(x) if x else None).round(2)
df = df.sort_values('mean_rank')

df['kws_rank'] = df['keywords'].apply(
    lambda kws : ', '.join(
        f'{kw} ({rank_dict[kw]:,})' for kw in sorted(kws, key=lambda kw:rank_dict[kw])
        )
    )

df['job_count'] = 1
pvt = df.pivot_table(
    index=['position', 'company', 'location', 'min_rank', 'mean_rank', 'kws_rank'],
    values='job_count',
    aggfunc='count'
    )
pvt = pvt.reset_index()
pvt = pvt.sort_values('mean_rank')
pvt = pvt.reset_index(drop=True)

# %%
df
# Out:
#                                                 position  \
# 5127           Community Health Nurse - Registered Nurse
# 5072           Community Health Nurse - Registered Nurse
# 5090           Community Health Nurse - Registered Nurse
# 5072           Community Health Nurse - Registered Nurse
# 5090           Community Health Nurse - Registered Nurse
# ...                                                  ...
# 17362                                              nanny
# 20877  Representante de AtenciÃ³n al Cliente de Distr...
# 16857                                       Policier- FR
# 16857                                       Policier- FR
# 20577                      Concepteur de Contenu Produit
#
#                        company                                   location  \
# 5127   Fraser Health Authority       Port Moody, British Columbia, Canada
# 5072   Fraser Health Authority          Burnaby, British Columbia, Canada
# 5090   Fraser Health Authority          Burnaby, British Columbia, Canada
# 5072   Fraser Health Authority          Burnaby, British Columbia, Canada
# 5090   Fraser Health Authority          Burnaby, British Columbia, Canada
# ...                        ...                                        ...
# 17362                   Sujata       White Rock, British Columbia, Canada
# 20877                      NFI            Delta, British Columbia, Canada
# 16857                       CN  North Vancouver, British Columbia, Canada
# 16857                       CN  North Vancouver, British Columbia, Canada
# 20577                    Cisco        Vancouver, British Columbia, Canada
#
#                       status  \
# 5127   Be an early applicant
# 5072   Be an early applicant
# 5090   Be an early applicant
# 5072   Be an early applicant
# 5090   Be an early applicant
# ...                      ...
# 17362  Be an early applicant
# 20877  Be an early applicant
# 16857  Be an early applicant
# 16857  Be an early applicant
# 20577  Be an early applicant
#
#                                                  job_url  \
# 5127   https://ca.linkedin.com/jobs/view/community-he...
# 5072   https://ca.linkedin.com/jobs/view/community-he...
# 5090   https://ca.linkedin.com/jobs/view/community-he...
# 5072   https://ca.linkedin.com/jobs/view/community-he...
# 5090   https://ca.linkedin.com/jobs/view/community-he...
# ...                                                  ...
# 17362  https://ca.linkedin.com/jobs/view/nanny-at-suj...
# 20877  https://ca.linkedin.com/jobs/view/representant...
# 16857  https://ca.linkedin.com/jobs/view/policier-fr-...
# 16857  https://ca.linkedin.com/jobs/view/policier-fr-...
# 20577  https://ca.linkedin.com/jobs/view/concepteur-d...
#
#                                                 firm_url  \
# 5127   https://ca.linkedin.com/company/fraser-health-...
# 5072   https://ca.linkedin.com/company/fraser-health-...
# 5090   https://ca.linkedin.com/company/fraser-health-...
# 5072   https://ca.linkedin.com/company/fraser-health-...
# 5090   https://ca.linkedin.com/company/fraser-health-...
# ...                                                  ...
# 17362  https://in.linkedin.com/company/sujata?trk=pub...
# 20877  https://www.linkedin.com/company/nfi?trk=publi...
# 16857  https://ca.linkedin.com/company/cn?trk=public_...
# 16857  https://ca.linkedin.com/company/cn?trk=public_...
# 20577  https://www.linkedin.com/company/cisco?trk=pub...
#
#                                                 keywords  \
# 5127   {health, community, authority, fraser, registe...
# 5072   {health, community, authority, fraser, registe...
# 5090   {health, community, authority, fraser, registe...
# 5072   {health, community, authority, fraser, registe...
# 5090   {health, community, authority, fraser, registe...
# ...                                                  ...
# 17362                                    {nanny, sujata}
# 20877  {atenciã, cliente, nfi, distribuciã, represent...
# 16857                                         {policier}
# 16857                                         {policier}
# 20577              {contenu, concepteur, cisco, produit}
#
#                            word_ranks  min_rank  mean_rank  \
# 5127             [0, 35, 1, 2, 10, 5]         0       8.83
# 5072             [0, 35, 1, 2, 10, 5]         0       8.83
# 5090             [0, 35, 1, 2, 10, 5]         0       8.83
# 5072             [0, 35, 1, 2, 10, 5]         0       8.83
# 5090             [0, 35, 1, 2, 10, 5]         0       8.83
# ...                               ...       ...        ...
# 17362                    [4996, 8266]      4996    6631.00
# 20877  [8297, 8313, 2544, 7870, 8406]      2544    7086.00
# 16857                          [7237]      7237    7237.00
# 16857                          [7237]      7237    7237.00
# 20577        [7938, 7956, 7474, 8332]      7474    7925.00
#
#                                                 kws_rank  job_count
# 5127   health (0), authority (1), fraser (2), nurse (...          1
# 5072   health (0), authority (1), fraser (2), nurse (...          1
# 5090   health (0), authority (1), fraser (2), nurse (...          1
# 5072   health (0), authority (1), fraser (2), nurse (...          1
# 5090   health (0), authority (1), fraser (2), nurse (...          1
# ...                                                  ...        ...
# 17362                      nanny (4,996), sujata (8,266)          1
# 20877  nfi (2,544), distribuciã (7,870), atenciã (8,2...          1
# 16857                                   policier (7,237)          1
# 16857                                   policier (7,237)          1
# 20577  cisco (7,474), contenu (7,938), concepteur (7,...          1
#
# [38240 rows x 12 columns]

# %%
includes = ['policy', 'research']
excludes = ['assistant', 'university']

# initialize condition
cond = pvt['kws_rank'].isna()

for w in includes:
    cond = cond | (pvt['kws_rank'].str.contains(w))

for w in excludes:
    cond = cond & (~pvt['kws_rank'].str.contains(w))


pvt[cond].reset_index(drop=True)
# Out:
#                                              position  \
# 0   Regional Medical Director - Learning and Research
# 1                       Coordinator, Research Finance
# 2                            Senior Research Engineer
# 3                                   Analyst, Research
# 4   Research Projects Coordinator, Medical Oncolog...
# ..                                                ...
# 70      Medical Image Annotation & Research Associate
# 71  Co-op Researcher - Multimodal Large Language M...
# 72                         Senior Security Researcher
# 73    Research Associate in Computational Mathematics
# 74                           Deep Learning Researcher
#
#                                  company  min_rank  mean_rank  \
# 0                Fraser Health Authority         0      75.00
# 1                Fraser Health Authority         0      76.67
# 2                                    RBC         6     100.00
# 3                              ITjobs.ca        44     106.00
# 4   Provincial Health Services Authority         0     107.82
# ..                                   ...       ...        ...
# 70                               Prenuvo        18    2037.67
# 71                         Huawei Canada        11    2083.70
# 72                  Truffle Security Co.         6    2222.00
# 73                               TIMEZYX        18    2519.00
# 74                             Picovoice       144    2788.25
#
#                                              kws_rank  job_count
# 0   health (0), authority (1), fraser (2), and (13...          2
# 1   health (0), authority (1), fraser (2), coordin...          2
# 2   senior (6), engineer (9), research (167), rbc ...          2
# 3          analyst (44), itjobs (107), research (167)          2
# 4   health (0), authority (1), vancouver (4), serv...          2
# ..                                                ...        ...
# 70  associate (18), medical (62), research (167), ...          2
# 71  canada (11), language (282), huawei (759), res...          2
# 72  senior (6), security (90), researcher (1,328),...          2
# 73  associate (18), research (167), mathematics (2...          2
# 74  learning (144), researcher (1,328), picovoice ...          1
#
# [75 rows x 6 columns]
